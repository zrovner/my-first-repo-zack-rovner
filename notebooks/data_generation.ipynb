# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
X,y = make_classification(n_samples=1000, n_features=10, n_informative=4, n_redundant=3, 
                                     n_repeated=0, n_classes=2, n_clusters_per_class=2,
                                     weights=None, flip_y=0.01, class_sep=1.0, hypercube=True,
                                     shift=0.0, scale=1.0, shuffle=True, random_state=None)

# %%
data = pd.DataFrame(data=X,columns=[f'Feature {col}' for col in range(1,11)])
data['Target'] = y

# %%
data.to_csv('../data/classification_data_set.csv',index=False)

# %%
sns.pairplot(df,hue='Target');

# %%
sns.displot(data,x='Feature 1',hue='Target')
